# %%
import pandas as pd;
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("test.csv")
data.std()
# Out:
# x    0.979221
# y    1.024023
# dtype: float64

# %%
x = data['x'].to_numpy()
y = data['y'].to_numpy()

# %%
sns.kdeplot(data, x='x', y='y', cmap='magma', thresh=0, fill=True, levels=100)
plt.gca().set_aspect('equal')
plt.xlim((-3, 3))
plt.ylim((-3, 3))
plt.show()
