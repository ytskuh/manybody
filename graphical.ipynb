# %%
import pandas as pd;
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("result3.csv")
data.std()
# Out:
# x    1.009316
# dtype: float64

# %%
x = data['x'].to_numpy()

# %%
sns.kdeplot(data, thresh=0, fill=True, levels=100)
plt.xlim((-3, 3))
plt.show()
