# %%
import pandas as pd;
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.animation import FuncAnimation

# %%
data = pd.read_csv("result5.csv")
data.std()
# Out:
# x    0.997336
# dtype: float64

# %%
x = data['x'].to_numpy()

# %%
len(data)
# Out:
# 3333500

# %%
fig, ax = plt.subplots()
sns.kdeplot(data.iloc[0:500], thresh=0, ax=ax)
line = ax.plot()

# %%
fig, ax = plt.subplots()

# %%
def update(frame):
    ax.clear()
    ax.set_xlim([-3, 3])
    sns.kdeplot(data.iloc[5000*frame:5000*(frame+1)], thresh=0, ax=ax)
    line = ax.plot()
    return line

# %%
ani = FuncAnimation(fig, update, frames=100, interval=50, blit=True)
ani.save('sin_wave.gif', writer='pillow')

# %%
sns.kdeplot(data.iloc[1000000:], thresh=0)
plt.xlim((-3, 3))
plt.show()
