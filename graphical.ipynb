# %%
import pandas as pd;
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("result.csv")
data.std()
# Out:
# x    1.030168
# dtype: float64

# %%
x = data['x'].to_numpy()

# %%
sns.kdeplot(data, cmap='magma', thresh=0, fill=True, levels=100)
plt.gca().set_aspect('equal')
plt.xlim((-3, 3))
plt.ylim((-3, 3))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 sns.kdeplot(data, cmap='magma', thresh=0, fill=True, levels=100)
#       2 plt.gca().set_aspect('equal')
#       3 plt.xlim((-3, 3))
#
# File /usr/lib/python3.10/site-packages/seaborn/distributions.py:1717, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1713 if p.univariate:
#    1715     plot_kws = kwargs.copy()
# -> 1717     p.plot_univariate_density(
#    1718         multiple=multiple,
#    1719         common_norm=common_norm,
#    1720         common_grid=common_grid,
#    1721         fill=fill,
#    1722         color=color,
#    1723         legend=legend,
# ...
